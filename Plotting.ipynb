# %% [markdown]
# <a href="https://colab.research.google.com/github/jeyam483/Plotting/blob/main/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression

dataframe = pd.read_csv("/content/Chocolate Sales.csv")
dataframe.head(5)
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_90['Boxes Shipped'].plot(kind='hist', bins=20, title='Boxes Shipped')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
plt.scatter(dataframe ['Product'], dataframe ['Country'])
plt.xlabel('Product')
plt.ylabel('Country')
plt.show()

# %%
x=dataframe ['Product'].values.reshape(-1,1)
y=dataframe ['Country'].values.reshape(-1,1)
print(x,y)
# Out:
# [['Mint Chip Choco']
#  ['85% Dark Bars']
#  ['Peanut Butter Cubes']
#  ...
#  ['Organic Choco Syrup']
#  ['Eclairs']
#  ['70% Dark Bites']] [['UK']
#  ['India']
#  ['India']
#  ...
#  ['Canada']
#  ['India']
#  ['India']]

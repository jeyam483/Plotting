# %% [markdown]
# <a href="https://colab.research.google.com/github/jeyam483/Plotting/blob/main/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
x=np.random.random((5,4))
print(x)
# Out:
# [[0.54048925 0.8427104  0.02488463 0.4290869 ]
#  [0.91763929 0.60897146 0.55606125 0.39458211]
#  [0.86892114 0.4150647  0.75580674 0.00658845]
#  [0.08999185 0.89735754 0.16972612 0.62221753]
#  [0.63812784 0.69373205 0.60902749 0.97767003]]

# %%
plt.plot(x,'*-')
x = np.linspace(0, 350, 150)
y = np.power(x, .15)
plt.plot(x, y, '+-')
plt.show()

# %%
sns.set()
sns.lineplot(x=y, y=y)
plt.show()

# %%
plt.plot(x,'*-')
plt.show()

# %% [markdown]
# Task With Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression

dataframe = pd.read_csv("/content/loan_data.csv")
dataframe.head()
dataframe.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
plt.scatter(dataframe ['person_age'], dataframe ['person_gender'])
plt.xlabel('person_age')
plt.ylabel('person_gender')
plt.show()

# %%
x=dataframe ['person_age'].values.reshape(-1,1)
y=dataframe ['person_gender'].values.reshape(-1,1)
print(x,y)
# Out:
# [[22.]
#  [21.]
#  [25.]
#  ...
#  [33.]
#  [29.]
#  [24.]] [['female']
#  ['female']
#  ['female']
#  ...
#  ['male']
#  ['male']
#  ['male']]

# %%
sns.countplot(x ='person_age', data = dataframe)
plt.show()

# %%
sns.countplot(y ='person_gender', data = dataframe)
plt.show()

# %%
sns.distplot(dataframe ["loan_amnt"])
plt.show()
# Out:
# <ipython-input-84-60122bcde0f9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe ["loan_amnt"])

# %%
sns.histplot(data=dataframe, x="loan_int_rate")
plt.show()

# %%
ax = sns.scatterplot(x="loan_amnt", y="loan_int_rate", data=dataframe)
plt.show()

# %%
ax = sns.boxplot(x="loan_percent_income", y="cb_person_cred_hist_length", data=dataframe)
plt.show()

# %%
ax = sns.boxplot(x = "person_age", y = "person_gender", data=dataframe)
plt.show()

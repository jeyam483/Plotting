# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
dataframe = pd.read_csv("/content/accident.csv")
print(dataframe.shape)
cars=dataframe.head(20)
ax = sns.scatterplot(x="Gender", y="Age",hue="Speed_of_Impact",size="Helmet_Used",data=cars)
plt.show()
# Out:
# (200, 6)
